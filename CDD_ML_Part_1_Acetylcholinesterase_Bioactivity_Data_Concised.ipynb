# %% [markdown]
# <a href="https://colab.research.google.com/github/iraajgangavaram/iraajgangavaram/blob/main/CDD_ML_Part_1_Acetylcholinesterase_Bioactivity_Data_Concised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 746.2 kB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.0 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.2 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 8   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 9   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
#
#                      organism  \
# 0                Homo sapiens
# 1                Homo sapiens
# 2     Drosophila melanogaster
# 3              Bemisia tabaci
# 4   Leptinotarsa decemlineata
# 5         Torpedo californica
# 6                Mus musculus
# 7           Rattus norvegicus
# 8    Electrophorus electricus
# 9                  Bos taurus
# 10          Anopheles gambiae
# 11     Nephotettix cincticeps
# 12              Gallus gallus
# 13                Danio rerio
# 14              Aedes aegypti
# 15            Musca domestica
# 16          Rattus norvegicus
# 17        Plutella xylostella
# 18            Musca domestica
# 19  Pediculus humanus capitis
# 20          Spodoptera litura
# 21      Laodelphax striatella
# 22        Schizaphis graminum
# 23     Caenorhabditis elegans
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   28.0
# 1                        Cholinesterases; ACHE & BCHE   28.0
# 2                                Acetylcholinesterase   18.0
# 3                                               AChE2   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   15.0
# 6                                Acetylcholinesterase   15.0
# 7                                Acetylcholinesterase   15.0
# 8                                Acetylcholinesterase   15.0
# 9                                Acetylcholinesterase   15.0
# 10                               Acetylcholinesterase   15.0
# 11               Ace-orthologous acetylcholinesterase   15.0
# 12                               Acetylcholinesterase   15.0
# 13                               Acetylcholinesterase   15.0
# 14                               Acetylcholinesterase   15.0
# 15                               Acetylcholinesterase   14.0
# 16  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 17                               Acetylcholinesterase   14.0
# 18                               Acetylcholinesterase   14.0
# 19                               Acetylcholinesterase   14.0
# 20                               Acetylcholinesterase   14.0
# 21                               Acetylcholinesterase   14.0
# 22                               Acetylcholinesterase   14.0
# 23                             Acetylcholinesterase 1   14.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL220
# 1                False    CHEMBL2095233
# 2                False    CHEMBL2242744
# 3                False    CHEMBL2366409
# 4                False    CHEMBL2366490
# 5                False       CHEMBL4780
# 6                False       CHEMBL3198
# 7                False       CHEMBL3199
# 8                False       CHEMBL4078
# 9                False       CHEMBL4768
# 10               False    CHEMBL2046266
# 11               False    CHEMBL2366514
# 12               False    CHEMBL3227914
# 13               False    CHEMBL3308995
# 14               False    CHEMBL4295607
# 15               False       CHEMBL5752
# 16               False    CHEMBL2111475
# 17               False    CHEMBL2242729
# 18               False    CHEMBL2242743
# 19               False    CHEMBL2362988
# 20               False    CHEMBL2366422
# 21               False    CHEMBL2366446
# 22               False    CHEMBL2366511
# 23               False    CHEMBL3341583
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 2   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 17  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 23  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     9606
# 1     9606
# 2     7227
# 3     7038
# 4     7539
# 5     7787
# 6    10090
# 7    10116
# 8     8005
# 9     9913
# 10    7165
# 11   94400
# 12    9031
# 13    7955
# 14    7159
# 15    7370
# 16   10116
# 17   51655
# 18    7370
# 19  121226
# 20   69820
# 21  195883
# 22   13262
# 23    6239

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL3198'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        72527                  []
# 1        None             None        73586                  []
# 2        None             None        74599                  []
#
#   assay_chembl_id                                 assay_description  \
# 0    CHEMBL638608  Inhibitory activity against acetylcholinesterase
# 1    CHEMBL638608  Inhibitory activity against acetylcholinesterase
# 2    CHEMBL638608  Inhibitory activity against acetylcholinesterase
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism      target_pref_name target_tax_id text_value  toid  type  \
# 0    Mus musculus  Acetylcholinesterase         10090       None  None  IC50
# 1    Mus musculus  Acetylcholinesterase         10090       None  None  IC50
# 2    Mus musculus  Acetylcholinesterase         10090       None  None  IC50
#
#   units    uo_units upper_value value
# 0    nM  UO_0000065        None   5.7
# 1    nM  UO_0000065        None  13.0
# 2    nM  UO_0000065        None   1.5
#
# [3 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-11-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 687  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 688  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 689  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 690  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 691  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# 0          72527                  []    CHEMBL638608
# 1          73586                  []    CHEMBL638608
# 2          74599                  []    CHEMBL638608
# 3          75755                  []    CHEMBL638608
# 4          76879                  []    CHEMBL638608
# ..           ...                 ...             ...
# 687     25002098                  []   CHEMBL5233377
# 688     25002099                  []   CHEMBL5233377
# 689     25002100                  []   CHEMBL5233377
# 690     25002101                  []   CHEMBL5233377
# 691     25002102                  []   CHEMBL5233377
#
#                                     assay_description assay_type  \
# 0    Inhibitory activity against acetylcholinesterase          B
# 1    Inhibitory activity against acetylcholinesterase          B
# 2    Inhibitory activity against acetylcholinesterase          B
# 3    Inhibitory activity against acetylcholinesterase          B
# 4    Inhibitory activity against acetylcholinesterase          B
# ..                                                ...        ...
# 687                    Inhibition of mouse brain AChE          B
# 688                    Inhibition of mouse brain AChE          B
# 689                    Inhibition of mouse brain AChE          B
# 690                    Inhibition of mouse brain AChE          B
# 691                    Inhibition of mouse brain AChE          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 687                    None                   None  BAO_0000190  ...
# 688                    None                   None  BAO_0000190  ...
# 689                    None                   None  BAO_0000190  ...
# 690                    None                   None  BAO_0000190  ...
# 691                    None                   None  BAO_0000190  ...
#
#     target_organism      target_pref_name target_tax_id text_value  toid  \
# 0      Mus musculus  Acetylcholinesterase         10090       None  None
# 1      Mus musculus  Acetylcholinesterase         10090       None  None
# 2      Mus musculus  Acetylcholinesterase         10090       None  None
# 3      Mus musculus  Acetylcholinesterase         10090       None  None
# 4      Mus musculus  Acetylcholinesterase         10090       None  None
# ..              ...                   ...           ...        ...   ...
# 687    Mus musculus  Acetylcholinesterase         10090       None  None
# 688    Mus musculus  Acetylcholinesterase         10090       None  None
# 689    Mus musculus  Acetylcholinesterase         10090       None  None
# 690    Mus musculus  Acetylcholinesterase         10090       None  None
# 691    Mus musculus  Acetylcholinesterase         10090       None  None
#
#      type units    uo_units upper_value   value
# 0    IC50    nM  UO_0000065        None     5.7
# 1    IC50    nM  UO_0000065        None    13.0
# 2    IC50    nM  UO_0000065        None     1.5
# 3    IC50    nM  UO_0000065        None  2100.0
# 4    IC50    nM  UO_0000065        None  4400.0
# ..    ...   ...         ...         ...     ...
# 687  IC50    uM  UO_0000065        None   0.065
# 688  IC50    uM  UO_0000065        None  0.0048
# 689  IC50    uM  UO_0000065        None  0.0076
# 690  IC50    uM  UO_0000065        None   0.034
# 691  IC50    uM  UO_0000065        None  0.0019
#
# [685 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 598

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 682  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 685  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 687  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 689  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 691  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# 0          72527                  []    CHEMBL638608
# 1          73586                  []    CHEMBL638608
# 2          74599                  []    CHEMBL638608
# 3          75755                  []    CHEMBL638608
# 4          76879                  []    CHEMBL638608
# ..           ...                 ...             ...
# 682     25002093                  []   CHEMBL5233377
# 685     25002096                  []   CHEMBL5233377
# 687     25002098                  []   CHEMBL5233377
# 689     25002100                  []   CHEMBL5233377
# 691     25002102                  []   CHEMBL5233377
#
#                                     assay_description assay_type  \
# 0    Inhibitory activity against acetylcholinesterase          B
# 1    Inhibitory activity against acetylcholinesterase          B
# 2    Inhibitory activity against acetylcholinesterase          B
# 3    Inhibitory activity against acetylcholinesterase          B
# 4    Inhibitory activity against acetylcholinesterase          B
# ..                                                ...        ...
# 682                    Inhibition of mouse brain AChE          B
# 685                    Inhibition of mouse brain AChE          B
# 687                    Inhibition of mouse brain AChE          B
# 689                    Inhibition of mouse brain AChE          B
# 691                    Inhibition of mouse brain AChE          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 682                    None                   None  BAO_0000190  ...
# 685                    None                   None  BAO_0000190  ...
# 687                    None                   None  BAO_0000190  ...
# 689                    None                   None  BAO_0000190  ...
# 691                    None                   None  BAO_0000190  ...
#
#     target_organism      target_pref_name target_tax_id text_value  toid  \
# 0      Mus musculus  Acetylcholinesterase         10090       None  None
# 1      Mus musculus  Acetylcholinesterase         10090       None  None
# 2      Mus musculus  Acetylcholinesterase         10090       None  None
# 3      Mus musculus  Acetylcholinesterase         10090       None  None
# 4      Mus musculus  Acetylcholinesterase         10090       None  None
# ..              ...                   ...           ...        ...   ...
# 682    Mus musculus  Acetylcholinesterase         10090       None  None
# 685    Mus musculus  Acetylcholinesterase         10090       None  None
# 687    Mus musculus  Acetylcholinesterase         10090       None  None
# 689    Mus musculus  Acetylcholinesterase         10090       None  None
# 691    Mus musculus  Acetylcholinesterase         10090       None  None
#
#      type units    uo_units upper_value   value
# 0    IC50    nM  UO_0000065        None     5.7
# 1    IC50    nM  UO_0000065        None    13.0
# 2    IC50    nM  UO_0000065        None     1.5
# 3    IC50    nM  UO_0000065        None  2100.0
# 4    IC50    nM  UO_0000065        None  4400.0
# ..    ...   ...         ...         ...     ...
# 682  IC50    uM  UO_0000065        None  0.0087
# 685  IC50    uM  UO_0000065        None  0.0022
# 687  IC50    uM  UO_0000065        None   0.065
# 689  IC50    uM  UO_0000065        None  0.0076
# 691  IC50    uM  UO_0000065        None  0.0019
#
# [598 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL1678   COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2.Cl
# 1         CHEMBL552871  COc1cc2c(c(OC)c1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1...
# 2         CHEMBL145446    COc1cc2c(cc1OC)C(=O)C(CCCC1CCN(Cc3ccccc3)CC1)C2
# 3         CHEMBL538050            Cl.O=C1c2ccccc2CCC1CC1CCN(Cc2ccccc2)CC1
# 4         CHEMBL543923      COc1cc2c(cc1OC)CC(CC1CCN(Cc3ccccc3)CC1)=C2.Cl
# ..                 ...                                                ...
# 682      CHEMBL5282048  CC1(C)O[C@H]2O[C@H](NCCCCCCCNc3c4c(nc5ccccc35)...
# 685      CHEMBL5288285  CC1(C)O[C@H]2O[C@H](CNCCCCCCCCCCCNc3c4c(nc5ccc...
# 687      CHEMBL5285687  CO[C@@H]1O[C@H](CNCCCCCCCCCCNc2c3c(nc4ccccc24)...
# 689      CHEMBL5272055  CC1(C)O[C@H]2[C@@H](O1)[C@@H](CNCCCCCCCCCCNc1c...
# 691      CHEMBL3752685  Cl.Cl.c1ccc2c(NCCCCCCCNc3c4c(nc5ccccc35)CCCC4)...
#
#     standard_value
# 0              5.7
# 1             13.0
# 2              1.5
# 3           2100.0
# 4           4400.0
# ..             ...
# 682            8.7
# 685            2.2
# 687           65.0
# 689            7.6
# 691            1.9
#
# [598 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL1678   COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2.Cl
# 1         CHEMBL552871  COc1cc2c(c(OC)c1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1...
# 2         CHEMBL145446    COc1cc2c(cc1OC)C(=O)C(CCCC1CCN(Cc3ccccc3)CC1)C2
# 3         CHEMBL538050            Cl.O=C1c2ccccc2CCC1CC1CCN(Cc2ccccc2)CC1
# 4         CHEMBL543923      COc1cc2c(cc1OC)CC(CC1CCN(Cc3ccccc3)CC1)=C2.Cl
# ..                 ...                                                ...
# 593      CHEMBL5282048  CC1(C)O[C@H]2O[C@H](NCCCCCCCNc3c4c(nc5ccccc35)...
# 594      CHEMBL5288285  CC1(C)O[C@H]2O[C@H](CNCCCCCCCCCCCNc3c4c(nc5ccc...
# 595      CHEMBL5285687  CO[C@@H]1O[C@H](CNCCCCCCCCCCNc2c3c(nc4ccccc24)...
# 596      CHEMBL5272055  CC1(C)O[C@H]2[C@@H](O1)[C@@H](CNCCCCCCCCCCNc1c...
# 597      CHEMBL3752685  Cl.Cl.c1ccc2c(NCCCCCCCNc3c4c(nc5ccccc35)CCCC4)...
#
#      standard_value         class
# 0               5.7        active
# 1              13.0        active
# 2               1.5        active
# 3            2100.0  intermediate
# 4            4400.0  intermediate
# ..              ...           ...
# 593             8.7        active
# 594             2.2        active
# 595            65.0        active
# 596             7.6        active
# 597             1.9        active
#
# [598 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 92%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 83%)

# %%
! ls -l
# Out:
# total 588
# -rw-r--r-- 1 root root 449219 Oct 30 19:25 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  43581 Oct 30 19:32 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  48795 Oct 30 19:33 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  52859 Oct 30 19:33 acetylcholinesterase.zip
# drwxr-xr-x 1 root root   4096 Oct 29 13:25 sample_data

# %% [markdown]
# ---
